# %%
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras.layers as tfl

# %%
file_path_train = '/Users/arun/Downloads/datasets/train_signs.h5'
file_path_test = '/Users/arun/Downloads/datasets/test_signs.h5'

# %%
with h5py.File(file_path_train, 'r') as h5_file:
    # List available datasets
    keys = list(h5_file.keys())
    print("Available datasets:", keys)
    
    # Example: Load datasets into numpy arrays
    classes = h5_file[keys[0]][()]
    train_x = h5_file[keys[1]][()]  # Read dataset as NumPy array
    train_y = h5_file[keys[2]][()]
# Out:
# Available datasets: ['list_classes', 'train_set_x', 'train_set_y']

# %%
with h5py.File(file_path_test, 'r') as h5_file:
    # List available datasets
    keys = list(h5_file.keys())
    print("Available datasets:", keys)
    
    # Example: Load datasets into numpy arrays
    classes = h5_file[keys[0]][()]
    test_x = h5_file[keys[1]][()]  # Read dataset as NumPy array
    test_y = h5_file[keys[2]][()]
# Out:
# Available datasets: ['list_classes', 'test_set_x', 'test_set_y']

# %%
train_x.shape, train_y.shape, test_x.shape, test_y.shape, classes.shape
# Out:
# ((1080, 64, 64, 3), (1080,), (120, 64, 64, 3), (120,), (6,))

# %%
index = 9
plt.imshow(train_x[index])
print ("y = " + str(np.squeeze(train_y[:, index])))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 index = 9
#       2 plt.imshow(train_x[index])
# ----> 3 print ("y = " + str(np.squeeze(train_y[:, index])))
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
def convert_to_one_hot(Y, C):
    return np.eye(C)[Y.reshape(-1)]

# %%
X_train = train_x/255
X_test = test_x/255
Y_train = convert_to_one_hot(train_y, 6)
Y_test = convert_to_one_hot(test_y, 6)

# %%
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
def convolutional_model(input_shape):

    input_img = tf.keras.Input(shape=input_shape)
    Z1 = tfl.Conv2D(8, 4, activation='linear', padding="same", strides=1)(input_img)
    A1 = tfl.ReLU()(Z1)
    P1 = tfl.MaxPool2D(pool_size=(8, 8), strides=(8, 8), padding='same')(A1)
    Z2 = tfl.Conv2D(16, 2, activation='linear', padding="same", strides=1)(P1)
    A2 = tfl.ReLU()(Z2)
    P2 = tfl.MaxPool2D(pool_size=(4, 4), strides=(4, 4), padding='same')(A2)
    F = tfl.Flatten()(P2)
    outputs = tfl.Dense(6, activation='softmax')(F)
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((64, 64, 3))
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
conv_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 8)      │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 64, 64, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 8, 8, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 8, 8, 16)       │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 2, 2, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,310 (5.12 KB)
#  Trainable params: 1,310 (5.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.1610 - loss: 1.8413 - val_accuracy: 0.1750 - val_loss: 1.7902
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1600 - loss: 1.7900 - val_accuracy: 0.2167 - val_loss: 1.7824
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2152 - loss: 1.7803 - val_accuracy: 0.2083 - val_loss: 1.7770
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2671 - loss: 1.7735 - val_accuracy: 0.2167 - val_loss: 1.7721
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3093 - loss: 1.7669 - val_accuracy: 0.2833 - val_loss: 1.7638
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3367 - loss: 1.7577 - val_accuracy: 0.3250 - val_loss: 1.7554
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3681 - loss: 1.7457 - val_accuracy: 0.3000 - val_loss: 1.7445
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4088 - loss: 1.7308 - val_accuracy: 0.3167 - val_loss: 1.7309
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4527 - loss: 1.7126 - val_accuracy: 0.3500 - val_loss: 1.7158
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4354 - loss: 1.6915 - val_accuracy: 0.3583 - val_loss: 1.6961
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4686 - loss: 1.6665 - val_accuracy: 0.4167 - val_loss: 1.6752
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4615 - loss: 1.6359 - val_accuracy: 0.4333 - val_loss: 1.6421
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5109 - loss: 1.5934 - val_accuracy: 0.4583 - val_loss: 1.6055
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5136 - loss: 1.5463 - val_accuracy: 0.4417 - val_loss: 1.5680
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5572 - loss: 1.4948 - val_accuracy: 0.4167 - val_loss: 1.5250
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5708 - loss: 1.4439 - val_accuracy: 0.4500 - val_loss: 1.4844
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5757 - loss: 1.3957 - val_accuracy: 0.4417 - val_loss: 1.4446
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5790 - loss: 1.3508 - val_accuracy: 0.4500 - val_loss: 1.4028
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5894 - loss: 1.3063 - val_accuracy: 0.4750 - val_loss: 1.3638
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6039 - loss: 1.2657 - val_accuracy: 0.4667 - val_loss: 1.3281
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6108 - loss: 1.2288 - val_accuracy: 0.4917 - val_loss: 1.2953
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6110 - loss: 1.1945 - val_accuracy: 0.5167 - val_loss: 1.2602
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6147 - loss: 1.1611 - val_accuracy: 0.5333 - val_loss: 1.2324
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6198 - loss: 1.1326 - val_accuracy: 0.5333 - val_loss: 1.2034
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6242 - loss: 1.1030 - val_accuracy: 0.5417 - val_loss: 1.1779
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6321 - loss: 1.0794 - val_accuracy: 0.5500 - val_loss: 1.1550
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6402 - loss: 1.0545 - val_accuracy: 0.5417 - val_loss: 1.1303
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6424 - loss: 1.0319 - val_accuracy: 0.5500 - val_loss: 1.1105
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6543 - loss: 1.0115 - val_accuracy: 0.5583 - val_loss: 1.0907
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6657 - loss: 0.9914 - val_accuracy: 0.5750 - val_loss: 1.0734
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6721 - loss: 0.9736 - val_accuracy: 0.5750 - val_loss: 1.0568
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6765 - loss: 0.9563 - val_accuracy: 0.5833 - val_loss: 1.0414
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6855 - loss: 0.9399 - val_accuracy: 0.6000 - val_loss: 1.0264
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6879 - loss: 0.9249 - val_accuracy: 0.5833 - val_loss: 1.0135
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6975 - loss: 0.9106 - val_accuracy: 0.6000 - val_loss: 1.0007
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7007 - loss: 0.8970 - val_accuracy: 0.6083 - val_loss: 0.9885
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7084 - loss: 0.8844 - val_accuracy: 0.6250 - val_loss: 0.9772
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7095 - loss: 0.8727 - val_accuracy: 0.6333 - val_loss: 0.9666
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7095 - loss: 0.8611 - val_accuracy: 0.6417 - val_loss: 0.9566
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7113 - loss: 0.8504 - val_accuracy: 0.6583 - val_loss: 0.9475
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7153 - loss: 0.8395 - val_accuracy: 0.6667 - val_loss: 0.9380
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7165 - loss: 0.8297 - val_accuracy: 0.6750 - val_loss: 0.9292
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7212 - loss: 0.8201 - val_accuracy: 0.6750 - val_loss: 0.9209
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7248 - loss: 0.8108 - val_accuracy: 0.6750 - val_loss: 0.9128
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7290 - loss: 0.8021 - val_accuracy: 0.6833 - val_loss: 0.9049
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7347 - loss: 0.7936 - val_accuracy: 0.6833 - val_loss: 0.8974
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7423 - loss: 0.7853 - val_accuracy: 0.6833 - val_loss: 0.8903
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7439 - loss: 0.7772 - val_accuracy: 0.6917 - val_loss: 0.8835
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7457 - loss: 0.7696 - val_accuracy: 0.7000 - val_loss: 0.8767
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7521 - loss: 0.7617 - val_accuracy: 0.7000 - val_loss: 0.8703
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7535 - loss: 0.7547 - val_accuracy: 0.7000 - val_loss: 0.8641
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7534 - loss: 0.7473 - val_accuracy: 0.7000 - val_loss: 0.8576
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7583 - loss: 0.7404 - val_accuracy: 0.7000 - val_loss: 0.8515
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7594 - loss: 0.7334 - val_accuracy: 0.7083 - val_loss: 0.8453
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7604 - loss: 0.7266 - val_accuracy: 0.7083 - val_loss: 0.8395
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7628 - loss: 0.7199 - val_accuracy: 0.7083 - val_loss: 0.8337
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7628 - loss: 0.7132 - val_accuracy: 0.7083 - val_loss: 0.8279
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7632 - loss: 0.7066 - val_accuracy: 0.7083 - val_loss: 0.8224
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7688 - loss: 0.7006 - val_accuracy: 0.7083 - val_loss: 0.8169
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7728 - loss: 0.6944 - val_accuracy: 0.7167 - val_loss: 0.8113
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7757 - loss: 0.6880 - val_accuracy: 0.7250 - val_loss: 0.8058
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7758 - loss: 0.6815 - val_accuracy: 0.7250 - val_loss: 0.8002
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7758 - loss: 0.6757 - val_accuracy: 0.7250 - val_loss: 0.7949
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7794 - loss: 0.6695 - val_accuracy: 0.7250 - val_loss: 0.7897
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7834 - loss: 0.6635 - val_accuracy: 0.7250 - val_loss: 0.7847
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7852 - loss: 0.6576 - val_accuracy: 0.7167 - val_loss: 0.7793
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7860 - loss: 0.6521 - val_accuracy: 0.7167 - val_loss: 0.7742
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7860 - loss: 0.6464 - val_accuracy: 0.7167 - val_loss: 0.7688
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7892 - loss: 0.6405 - val_accuracy: 0.7167 - val_loss: 0.7636
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7871 - loss: 0.6350 - val_accuracy: 0.7167 - val_loss: 0.7586
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7907 - loss: 0.6293 - val_accuracy: 0.7167 - val_loss: 0.7533
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7919 - loss: 0.6237 - val_accuracy: 0.7167 - val_loss: 0.7481
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7929 - loss: 0.6182 - val_accuracy: 0.7167 - val_loss: 0.7429
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7926 - loss: 0.6127 - val_accuracy: 0.7167 - val_loss: 0.7383
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7986 - loss: 0.6074 - val_accuracy: 0.7167 - val_loss: 0.7336
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7987 - loss: 0.6019 - val_accuracy: 0.7167 - val_loss: 0.7294
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8017 - loss: 0.5968 - val_accuracy: 0.7167 - val_loss: 0.7248
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8014 - loss: 0.5919 - val_accuracy: 0.7250 - val_loss: 0.7199
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8039 - loss: 0.5867 - val_accuracy: 0.7167 - val_loss: 0.7153
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8066 - loss: 0.5819 - val_accuracy: 0.7333 - val_loss: 0.7106
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8101 - loss: 0.5766 - val_accuracy: 0.7417 - val_loss: 0.7063
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8080 - loss: 0.5718 - val_accuracy: 0.7417 - val_loss: 0.7021
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8110 - loss: 0.5670 - val_accuracy: 0.7417 - val_loss: 0.6982
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8099 - loss: 0.5622 - val_accuracy: 0.7417 - val_loss: 0.6940
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8116 - loss: 0.5571 - val_accuracy: 0.7417 - val_loss: 0.6898
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8164 - loss: 0.5522 - val_accuracy: 0.7417 - val_loss: 0.6861
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8165 - loss: 0.5471 - val_accuracy: 0.7500 - val_loss: 0.6820
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8189 - loss: 0.5427 - val_accuracy: 0.7500 - val_loss: 0.6786
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8191 - loss: 0.5384 - val_accuracy: 0.7500 - val_loss: 0.6744
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8200 - loss: 0.5342 - val_accuracy: 0.7500 - val_loss: 0.6709
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8237 - loss: 0.5298 - val_accuracy: 0.7583 - val_loss: 0.6677
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8280 - loss: 0.5253 - val_accuracy: 0.7583 - val_loss: 0.6638
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8288 - loss: 0.5212 - val_accuracy: 0.7583 - val_loss: 0.6611
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8376 - loss: 0.5161 - val_accuracy: 0.7500 - val_loss: 0.6576
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8383 - loss: 0.5126 - val_accuracy: 0.7500 - val_loss: 0.6547
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8379 - loss: 0.5084 - val_accuracy: 0.7583 - val_loss: 0.6516
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8376 - loss: 0.5043 - val_accuracy: 0.7583 - val_loss: 0.6490
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8409 - loss: 0.5005 - val_accuracy: 0.7583 - val_loss: 0.6458
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8429 - loss: 0.4965 - val_accuracy: 0.7583 - val_loss: 0.6430
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8438 - loss: 0.4929 - val_accuracy: 0.7667 - val_loss: 0.6399

# %%
history.history
# Out:
# {'accuracy': [0.16296295821666718,
#   0.17037037014961243,
#   0.23240740597248077,
#   0.2527777850627899,
#   0.3166666626930237,
#   0.32685184478759766,
#   0.3620370328426361,
#   0.3907407522201538,
#   0.4287036955356598,
#   0.42500001192092896,
#   0.44999998807907104,
#   0.4564814865589142,
#   0.49074074625968933,
#   0.5027777552604675,
#   0.5314815044403076,
#   0.5472221970558167,
#   0.5537037253379822,
#   0.5675926208496094,
#   0.5731481313705444,
#   0.5898148417472839,
#   0.5972222089767456,
#   0.6018518805503845,
#   0.605555534362793,
#   0.614814817905426,
#   0.6240741014480591,
#   0.635185182094574,
#   0.6407407522201538,
#   0.645370364189148,
#   0.6564815044403076,
#   0.6657407283782959,
#   0.6712962985038757,
#   0.675000011920929,
#   0.6842592358589172,
#   0.6888889074325562,
#   0.6953703761100769,
#   0.6972222328186035,
#   0.7027778029441833,
#   0.7046296000480652,
#   0.7046296000480652,
#   0.7074074149131775,
#   0.7138888835906982,
#   0.7166666388511658,
#   0.7212963104248047,
#   0.7240740656852722,
#   0.730555534362793,
#   0.7333333492279053,
#   0.7407407164573669,
#   0.7444444298744202,
#   0.7462962865829468,
#   0.7518518567085266,
#   0.7546296119689941,
#   0.7546296119689941,
#   0.760185182094574,
#   0.7620370388031006,
#   0.7638888955116272,
#   0.7685185074806213,
#   0.7685185074806213,
#   0.769444465637207,
#   0.7731481194496155,
#   0.7768518328666687,
#   0.7787036895751953,
#   0.779629647731781,
#   0.779629647731781,
#   0.7833333611488342,
#   0.7870370149612427,
#   0.789814829826355,
#   0.7907407283782959,
#   0.7907407283782959,
#   0.7925925850868225,
#   0.7916666865348816,
#   0.7935185432434082,
#   0.7953703999519348,
#   0.7972221970558167,
#   0.8009259104728699,
#   0.8046296238899231,
#   0.8055555820465088,
#   0.8101851940155029,
#   0.8111110925674438,
#   0.8120370507240295,
#   0.8138889074325562,
#   0.8148148059844971,
#   0.8138889074325562,
#   0.8157407641410828,
#   0.8166666626930237,
#   0.8185185194015503,
#   0.8212962746620178,
#   0.8222222328186035,
#   0.8259259462356567,
#   0.8268518447875977,
#   0.8277778029441833,
#   0.8324074149131775,
#   0.8370370268821716,
#   0.8379629850387573,
#   0.8435184955596924,
#   0.8462963104248047,
#   0.8462963104248047,
#   0.8472222089767456,
#   0.8472222089767456,
#   0.8490740656852722,
#   0.8509259223937988],
#  'loss': [1.815924048423767,
#   1.7868951559066772,
#   1.7792150974273682,
#   1.7730417251586914,
#   1.7656346559524536,
#   1.7563813924789429,
#   1.7443064451217651,
#   1.7297239303588867,
#   1.7117735147476196,
#   1.691334843635559,
#   1.6664718389511108,
#   1.6360759735107422,
#   1.59335458278656,
#   1.5474129915237427,
#   1.4983222484588623,
#   1.4501813650131226,
#   1.4045246839523315,
#   1.3602657318115234,
#   1.317404866218567,
#   1.2777180671691895,
#   1.2410935163497925,
#   1.206005334854126,
#   1.1734347343444824,
#   1.1434425115585327,
#   1.114369511604309,
#   1.089874029159546,
#   1.0636907815933228,
#   1.0414788722991943,
#   1.0201287269592285,
#   0.9995594024658203,
#   0.9808771014213562,
#   0.9629113078117371,
#   0.9455468058586121,
#   0.9304818511009216,
#   0.9156602621078491,
#   0.9016574621200562,
#   0.8888364434242249,
#   0.8766703009605408,
#   0.864938497543335,
#   0.8539367318153381,
#   0.8427591323852539,
#   0.8326841592788696,
#   0.822693407535553,
#   0.8130561709403992,
#   0.8040485382080078,
#   0.7952215075492859,
#   0.7866825461387634,
#   0.7784010171890259,
#   0.7704712152481079,
#   0.762326717376709,
#   0.7550650835037231,
#   0.7474429607391357,
#   0.7404022812843323,
#   0.7331482172012329,
#   0.726284384727478,
#   0.7194972038269043,
#   0.7125966548919678,
#   0.7059038877487183,
#   0.6995236277580261,
#   0.693166196346283,
#   0.6868026256561279,
#   0.6803838610649109,
#   0.6745506525039673,
#   0.6683351993560791,
#   0.6622193455696106,
#   0.6561545729637146,
#   0.6506565809249878,
#   0.6450228095054626,
#   0.6392407417297363,
#   0.6335911154747009,
#   0.6278985142707825,
#   0.6223450303077698,
#   0.6168829798698425,
#   0.6113895177841187,
#   0.6060241460800171,
#   0.6005825400352478,
#   0.5953621864318848,
#   0.5903648734092712,
#   0.5852863192558289,
#   0.5802574157714844,
#   0.5751945972442627,
#   0.5703367590904236,
#   0.565457820892334,
#   0.5607156157493591,
#   0.5557863712310791,
#   0.5511782765388489,
#   0.5459892153739929,
#   0.5415173768997192,
#   0.5370389223098755,
#   0.5326700210571289,
#   0.5281094312667847,
#   0.5235679745674133,
#   0.5194635391235352,
#   0.5143340229988098,
#   0.510373592376709,
#   0.5061535835266113,
#   0.5017297863960266,
#   0.4976491928100586,
#   0.49348071217536926,
#   0.48966312408447266],
#  'val_accuracy': [0.17499999701976776,
#   0.21666666865348816,
#   0.2083333283662796,
#   0.21666666865348816,
#   0.28333333134651184,
#   0.32499998807907104,
#   0.30000001192092896,
#   0.3166666626930237,
#   0.3499999940395355,
#   0.3583333194255829,
#   0.4166666567325592,
#   0.4333333373069763,
#   0.4583333432674408,
#   0.4416666626930237,
#   0.4166666567325592,
#   0.44999998807907104,
#   0.4416666626930237,
#   0.44999998807907104,
#   0.4749999940395355,
#   0.46666666865348816,
#   0.49166667461395264,
#   0.5166666507720947,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5416666865348816,
#   0.550000011920929,
#   0.5416666865348816,
#   0.550000011920929,
#   0.5583333373069763,
#   0.574999988079071,
#   0.574999988079071,
#   0.5833333134651184,
#   0.6000000238418579,
#   0.5833333134651184,
#   0.6000000238418579,
#   0.6083333492279053,
#   0.625,
#   0.6333333253860474,
#   0.6416666507720947,
#   0.6583333611488342,
#   0.6666666865348816,
#   0.675000011920929,
#   0.675000011920929,
#   0.675000011920929,
#   0.6833333373069763,
#   0.6833333373069763,
#   0.6833333373069763,
#   0.6916666626930237,
#   0.699999988079071,
#   0.699999988079071,
#   0.699999988079071,
#   0.699999988079071,
#   0.699999988079071,
#   0.7083333134651184,
#   0.7083333134651184,
#   0.7083333134651184,
#   0.7083333134651184,
#   0.7083333134651184,
#   0.7083333134651184,
#   0.7166666388511658,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7166666388511658,
#   0.7250000238418579,
#   0.7166666388511658,
#   0.7333333492279053,
#   0.7416666746139526,
#   0.7416666746139526,
#   0.7416666746139526,
#   0.7416666746139526,
#   0.7416666746139526,
#   0.7416666746139526,
#   0.75,
#   0.75,
#   0.75,
#   0.75,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.75,
#   0.75,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7666666507720947],
#  'val_loss': [1.7902263402938843,
#   1.7824413776397705,
#   1.7770391702651978,
#   1.7721145153045654,
#   1.7637786865234375,
#   1.755407691001892,
#   1.7445180416107178,
#   1.7309099435806274,
#   1.715790033340454,
#   1.6961376667022705,
#   1.67515230178833,
#   1.6421377658843994,
#   1.6055026054382324,
#   1.567973017692566,
#   1.5249724388122559,
#   1.4844157695770264,
#   1.4446250200271606,
#   1.4027504920959473,
#   1.3638495206832886,
#   1.328113079071045,
#   1.2953284978866577,
#   1.260176420211792,
#   1.2323744297027588,
#   1.2033928632736206,
#   1.1778851747512817,
#   1.1550190448760986,
#   1.1302894353866577,
#   1.1105115413665771,
#   1.0907433032989502,
#   1.073438286781311,
#   1.0568434000015259,
#   1.0413525104522705,
#   1.0264403820037842,
#   1.013526439666748,
#   1.0006651878356934,
#   0.9884805083274841,
#   0.977216899394989,
#   0.9665791392326355,
#   0.9565727710723877,
#   0.9474738240242004,
#   0.9379503726959229,
#   0.9292433261871338,
#   0.9208602905273438,
#   0.9128037691116333,
#   0.904904305934906,
#   0.8974347710609436,
#   0.8903223872184753,
#   0.8835245370864868,
#   0.8767125606536865,
#   0.8702823519706726,
#   0.8640885949134827,
#   0.8575774431228638,
#   0.8514759540557861,
#   0.845340371131897,
#   0.8395211696624756,
#   0.8337433934211731,
#   0.8278826475143433,
#   0.8223660588264465,
#   0.816914975643158,
#   0.8113168478012085,
#   0.805759072303772,
#   0.800204336643219,
#   0.7948894500732422,
#   0.7896929383277893,
#   0.7847216129302979,
#   0.7793387174606323,
#   0.7741529941558838,
#   0.768814206123352,
#   0.763606071472168,
#   0.7585586309432983,
#   0.7533419728279114,
#   0.7481459379196167,
#   0.7428534626960754,
#   0.7383077144622803,
#   0.7335901260375977,
#   0.7293663024902344,
#   0.7247580289840698,
#   0.7198594808578491,
#   0.7153187990188599,
#   0.7105895280838013,
#   0.7062749266624451,
#   0.7021380066871643,
#   0.6982435584068298,
#   0.6939828395843506,
#   0.6898066401481628,
#   0.68605637550354,
#   0.6820040345191956,
#   0.6786481142044067,
#   0.6744042634963989,
#   0.6709046959877014,
#   0.667659342288971,
#   0.6638053059577942,
#   0.6610612273216248,
#   0.6576128005981445,
#   0.654670774936676,
#   0.651646614074707,
#   0.6490329504013062,
#   0.6457818150520325,
#   0.6430037021636963,
#   0.6398518681526184]}

# %%
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /var/folders/xz/_q1lhz9n52lb8rsrv2yy36dm0000gn/T/ipykernel_3704/974158325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# /var/folders/xz/_q1lhz9n52lb8rsrv2yy36dm0000gn/T/ipykernel_3704/974158325.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]
